# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# 생성자 모델 만들기
generator = Sequential()
generator.add(Dense(128 * 7 * 7, input_dim = 100, activation = LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size = 5, padding = 'same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size = 5, padding='same', activation = 'tanh'))

# %%
# 판별자 모델 만들기
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size = 5, strides = 2, input_shape = (28, 28, 1), padding = 'same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size = 5, strides = 2, padding = 'same'))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation = 'sigmoid'))
discriminator.compile(loss = 'binary_crossentropy', optimizer = 'adam')
discriminator.trainable = False

# %%
# 생성자와 판별자 모델을 연결시키는 gan
ginput = Input(shape = (100, ))

# %%
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss = 'binary_crossentropy', optimizer = 'adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7101  g_loss:0.6986
# epoch:1  d_loss:0.4348  g_loss:0.3323
# epoch:2  d_loss:0.5332  g_loss:0.1001
# epoch:3  d_loss:0.7525  g_loss:0.0610
# epoch:4  d_loss:0.6897  g_loss:0.1291
# epoch:5  d_loss:0.5406  g_loss:0.3776
# epoch:6  d_loss:0.4938  g_loss:0.7601
# epoch:7  d_loss:0.5135  g_loss:0.9300
# epoch:8  d_loss:0.5170  g_loss:1.0348
# epoch:9  d_loss:0.4713  g_loss:0.9867
# epoch:10  d_loss:0.4003  g_loss:0.9850
# epoch:11  d_loss:0.3561  g_loss:0.9798
# epoch:12  d_loss:0.3668  g_loss:0.9473
# epoch:13  d_loss:0.2789  g_loss:0.9041
# epoch:14  d_loss:0.4284  g_loss:0.8314
# epoch:15  d_loss:0.5065  g_loss:0.6804
# epoch:16  d_loss:0.5457  g_loss:1.1380
# epoch:17  d_loss:0.6547  g_loss:0.9659
# epoch:18  d_loss:0.7113  g_loss:0.6186
# epoch:19  d_loss:0.5420  g_loss:0.8030
# epoch:20  d_loss:0.6327  g_loss:0.7491
# epoch:21  d_loss:0.6356  g_loss:0.8646
# epoch:22  d_loss:0.6120  g_loss:0.8721
# epoch:23  d_loss:0.5012  g_loss:0.8007
# epoch:24  d_loss:0.5263  g_loss:0.7855
# epoch:25  d_loss:0.5256  g_loss:0.7646
# epoch:26  d_loss:0.5076  g_loss:0.7934
# epoch:27  d_loss:0.5468  g_loss:0.6739
# epoch:28  d_loss:0.5215  g_loss:0.6970
# epoch:29  d_loss:0.5585  g_loss:0.6750
# epoch:30  d_loss:0.4895  g_loss:0.6469
# epoch:31  d_loss:0.4927  g_loss:0.7764
# epoch:32  d_loss:0.4915  g_loss:0.7090
# epoch:33  d_loss:0.4458  g_loss:0.8602
# epoch:34  d_loss:0.3907  g_loss:0.9483
# epoch:35  d_loss:0.4424  g_loss:0.9127
# epoch:36  d_loss:0.4278  g_loss:0.9468
# epoch:37  d_loss:0.4067  g_loss:0.8718
# epoch:38  d_loss:0.3962  g_loss:1.1131
# epoch:39  d_loss:0.2977  g_loss:0.9922
# epoch:40  d_loss:0.3047  g_loss:1.1816
# epoch:41  d_loss:0.3879  g_loss:1.1836
# epoch:42  d_loss:0.3670  g_loss:1.1428
# epoch:43  d_loss:0.2694  g_loss:1.4289
# epoch:44  d_loss:0.2221  g_loss:1.5657
# epoch:45  d_loss:0.2168  g_loss:1.9396
# epoch:46  d_loss:0.2658  g_loss:2.0803
# epoch:47  d_loss:0.1677  g_loss:2.3594
# epoch:48  d_loss:0.1576  g_loss:2.2955
# epoch:49  d_loss:0.1587  g_loss:2.6420
# epoch:50  d_loss:0.1225  g_loss:2.7804
# epoch:51  d_loss:0.1652  g_loss:2.9547
# epoch:52  d_loss:0.1240  g_loss:2.6738
# epoch:53  d_loss:0.2119  g_loss:2.3060
# epoch:54  d_loss:0.2007  g_loss:2.7538
# epoch:55  d_loss:0.3359  g_loss:2.4086
# epoch:56  d_loss:0.6592  g_loss:1.8188
# epoch:57  d_loss:0.3132  g_loss:2.2887
# epoch:58  d_loss:0.2086  g_loss:3.1095
# epoch:59  d_loss:0.1304  g_loss:3.2105
# epoch:60  d_loss:0.1174  g_loss:2.5486
# epoch:61  d_loss:0.0810  g_loss:2.3967
# epoch:62  d_loss:0.1188  g_loss:3.2467
# epoch:63  d_loss:0.1449  g_loss:3.3398
# epoch:64  d_loss:0.1774  g_loss:3.6148
# epoch:65  d_loss:0.4550  g_loss:3.4618
# epoch:66  d_loss:0.5920  g_loss:3.0212
# epoch:67  d_loss:0.2961  g_loss:4.6630
# epoch:68  d_loss:1.2013  g_loss:2.4253
# epoch:69  d_loss:0.9589  g_loss:1.8648
# epoch:70  d_loss:0.5821  g_loss:2.3436
# epoch:71  d_loss:0.4828  g_loss:3.6407
# epoch:72  d_loss:0.5590  g_loss:3.1125
# epoch:73  d_loss:0.4962  g_loss:2.3795
# epoch:74  d_loss:0.3454  g_loss:3.0036
# epoch:75  d_loss:0.3710  g_loss:3.5481
# epoch:76  d_loss:0.4789  g_loss:2.5707
# epoch:77  d_loss:0.5063  g_loss:2.1251
# epoch:78  d_loss:0.5162  g_loss:1.9233
# epoch:79  d_loss:0.5448  g_loss:1.7466
# epoch:80  d_loss:0.6731  g_loss:1.6018
# epoch:81  d_loss:0.7060  g_loss:1.4800
# epoch:82  d_loss:0.5697  g_loss:1.3572
# epoch:83  d_loss:0.7454  g_loss:1.1887
# epoch:84  d_loss:0.6572  g_loss:1.2289
# epoch:85  d_loss:0.5669  g_loss:1.4212
# epoch:86  d_loss:0.5069  g_loss:2.0861
# epoch:87  d_loss:0.4505  g_loss:2.0983
# epoch:88  d_loss:0.4061  g_loss:2.0756
# epoch:89  d_loss:0.3780  g_loss:2.5449
# epoch:90  d_loss:0.1945  g_loss:3.0574
# epoch:91  d_loss:0.2112  g_loss:3.5490
# epoch:92  d_loss:0.3089  g_loss:3.4933
# epoch:93  d_loss:0.2650  g_loss:3.1654
# epoch:94  d_loss:0.3839  g_loss:2.7981
# epoch:95  d_loss:0.4233  g_loss:2.9046
# epoch:96  d_loss:0.3944  g_loss:3.6427
# epoch:97  d_loss:0.8562  g_loss:2.5799
# epoch:98  d_loss:1.0967  g_loss:2.3532
# epoch:99  d_loss:0.7868  g_loss:3.2402
# epoch:100  d_loss:0.8114  g_loss:3.3560
# epoch:101  d_loss:0.8835  g_loss:2.4578
# epoch:102  d_loss:0.7960  g_loss:1.9266
# epoch:103  d_loss:0.6996  g_loss:1.6729
# epoch:104  d_loss:0.6262  g_loss:1.3889
# epoch:105  d_loss:0.5010  g_loss:1.4766
# epoch:106  d_loss:0.5139  g_loss:1.3956
# epoch:107  d_loss:0.4094  g_loss:1.8319
# epoch:108  d_loss:0.4755  g_loss:1.6280
# epoch:109  d_loss:0.4625  g_loss:1.7215
# epoch:110  d_loss:0.3560  g_loss:1.4905
# epoch:111  d_loss:0.4655  g_loss:1.3711
# epoch:112  d_loss:0.3353  g_loss:1.2430
# epoch:113  d_loss:0.4004  g_loss:1.1943
# epoch:114  d_loss:0.4493  g_loss:1.0974
# epoch:115  d_loss:0.4071  g_loss:1.0246
# epoch:116  d_loss:0.4285  g_loss:1.2035
# epoch:117  d_loss:0.4177  g_loss:1.2023
# epoch:118  d_loss:0.4259  g_loss:1.2848
# epoch:119  d_loss:0.3206  g_loss:1.1504
# epoch:120  d_loss:0.4871  g_loss:1.2172
# epoch:121  d_loss:0.5264  g_loss:0.9650
# epoch:122  d_loss:0.7063  g_loss:0.9110
# epoch:123  d_loss:0.4893  g_loss:1.0795
# epoch:124  d_loss:0.4791  g_loss:0.9780
# epoch:125  d_loss:0.6763  g_loss:1.1302
# epoch:126  d_loss:0.5348  g_loss:1.3149
# epoch:127  d_loss:0.5786  g_loss:1.4128
# epoch:128  d_loss:0.5516  g_loss:1.2288
# epoch:129  d_loss:0.5386  g_loss:1.3009
# epoch:130  d_loss:0.5569  g_loss:1.1391
# epoch:131  d_loss:0.5633  g_loss:1.2441
# epoch:132  d_loss:0.5053  g_loss:1.2008
# epoch:133  d_loss:0.6163  g_loss:1.1945
# epoch:134  d_loss:0.4353  g_loss:1.1687
# epoch:135  d_loss:0.4698  g_loss:1.3521
# epoch:136  d_loss:0.4710  g_loss:1.6319
# epoch:137  d_loss:0.3615  g_loss:1.7909
# epoch:138  d_loss:0.4795  g_loss:1.9028
# epoch:139  d_loss:0.5326  g_loss:1.7866
# epoch:140  d_loss:0.3683  g_loss:2.0656
# epoch:141  d_loss:0.5349  g_loss:2.2640
# epoch:142  d_loss:0.4627  g_loss:2.0277
# epoch:143  d_loss:0.4674  g_loss:1.9774
# epoch:144  d_loss:0.4139  g_loss:2.1753
# epoch:145  d_loss:0.3642  g_loss:1.9511
# epoch:146  d_loss:0.4262  g_loss:1.7228
# epoch:147  d_loss:0.5026  g_loss:1.8118
# epoch:148  d_loss:0.6167  g_loss:1.6548
# epoch:149  d_loss:0.5058  g_loss:1.6635
# epoch:150  d_loss:0.4171  g_loss:1.7991
# epoch:151  d_loss:0.6485  g_loss:1.9599
# epoch:152  d_loss:0.6801  g_loss:1.8223
# epoch:153  d_loss:0.6161  g_loss:2.0843
# epoch:154  d_loss:0.5410  g_loss:1.6558
# epoch:155  d_loss:0.5124  g_loss:1.4987
# epoch:156  d_loss:0.6351  g_loss:1.2458
# epoch:157  d_loss:0.5831  g_loss:1.4663
# epoch:158  d_loss:0.5106  g_loss:1.5381
# epoch:159  d_loss:0.4076  g_loss:1.7555
# epoch:160  d_loss:0.4344  g_loss:1.6767
# epoch:161  d_loss:0.4802  g_loss:1.7239
# epoch:162  d_loss:0.4582  g_loss:1.5906
# epoch:163  d_loss:0.4368  g_loss:1.8407
# epoch:164  d_loss:0.3298  g_loss:1.7157
# epoch:165  d_loss:0.3164  g_loss:1.4327
# epoch:166  d_loss:0.3939  g_loss:1.4874
# epoch:167  d_loss:0.3497  g_loss:1.8098
# epoch:168  d_loss:0.3122  g_loss:1.9611
# epoch:169  d_loss:0.3610  g_loss:1.8381
# epoch:170  d_loss:0.3393  g_loss:1.7230
# epoch:171  d_loss:0.4452  g_loss:1.8109
# epoch:172  d_loss:0.3754  g_loss:1.7335
# epoch:173  d_loss:0.3048  g_loss:1.9768
# epoch:174  d_loss:0.3716  g_loss:1.9269
# epoch:175  d_loss:0.3527  g_loss:2.1082
# epoch:176  d_loss:0.5030  g_loss:1.7736
# epoch:177  d_loss:0.4736  g_loss:1.8207
# epoch:178  d_loss:0.4842  g_loss:1.3676
# epoch:179  d_loss:0.4077  g_loss:1.6388
# epoch:180  d_loss:0.5095  g_loss:1.4826
# epoch:181  d_loss:0.4158  g_loss:1.9772
# epoch:182  d_loss:0.4706  g_loss:2.1423
# epoch:183  d_loss:0.6014  g_loss:1.8010
# epoch:184  d_loss:0.6103  g_loss:1.3417
# epoch:185  d_loss:0.5912  g_loss:1.3977
# epoch:186  d_loss:0.5633  g_loss:1.4165
# epoch:187  d_loss:0.5338  g_loss:1.5192
# epoch:188  d_loss:0.6027  g_loss:1.5855
# epoch:189  d_loss:0.7174  g_loss:1.4468
# epoch:190  d_loss:0.5427  g_loss:1.6025
# epoch:191  d_loss:0.6181  g_loss:1.4689
# epoch:192  d_loss:0.5167  g_loss:1.4493
# epoch:193  d_loss:0.6223  g_loss:1.4547
# epoch:194  d_loss:0.5703  g_loss:1.4054
# epoch:195  d_loss:0.5627  g_loss:1.3529
# epoch:196  d_loss:0.5115  g_loss:1.7305
# epoch:197  d_loss:0.5157  g_loss:2.0848
# epoch:198  d_loss:0.4824  g_loss:1.6596
# epoch:199  d_loss:0.4604  g_loss:1.5834
# epoch:200  d_loss:0.6176  g_loss:1.4566
# epoch:201  d_loss:0.5360  g_loss:1.4426
# epoch:202  d_loss:0.4077  g_loss:1.7519
# epoch:203  d_loss:0.4163  g_loss:1.7669
# epoch:204  d_loss:0.3561  g_loss:2.1526
# epoch:205  d_loss:0.3707  g_loss:2.1649
# epoch:206  d_loss:0.4725  g_loss:2.3751
# epoch:207  d_loss:0.5253  g_loss:1.8086
# epoch:208  d_loss:0.4878  g_loss:1.7412
# epoch:209  d_loss:0.4506  g_loss:1.7564
# epoch:210  d_loss:0.3761  g_loss:2.0756
# epoch:211  d_loss:0.4027  g_loss:2.1670
# epoch:212  d_loss:0.5965  g_loss:1.7501
# epoch:213  d_loss:0.5894  g_loss:1.7532
# epoch:214  d_loss:0.5780  g_loss:1.5785
# epoch:215  d_loss:0.4207  g_loss:1.6193
# epoch:216  d_loss:0.4772  g_loss:2.0876
# epoch:217  d_loss:0.4409  g_loss:1.7222
# epoch:218  d_loss:0.5552  g_loss:1.9989
# epoch:219  d_loss:0.5206  g_loss:1.7474
# epoch:220  d_loss:0.5341  g_loss:1.5364
# epoch:221  d_loss:0.5337  g_loss:1.4986
# epoch:222  d_loss:0.4206  g_loss:1.6520
# epoch:223  d_loss:0.4418  g_loss:1.7668
# epoch:224  d_loss:0.4427  g_loss:1.9468
# epoch:225  d_loss:0.3873  g_loss:2.3439
# epoch:226  d_loss:0.4652  g_loss:1.9915
# epoch:227  d_loss:0.4840  g_loss:1.8571
# epoch:228  d_loss:0.5967  g_loss:1.7597
# epoch:229  d_loss:0.4294  g_loss:1.6004
# epoch:230  d_loss:0.5412  g_loss:1.7064
# epoch:231  d_loss:0.5619  g_loss:1.8834
# epoch:232  d_loss:0.5397  g_loss:2.0719
# epoch:233  d_loss:0.3988  g_loss:2.0555
# epoch:234  d_loss:0.3881  g_loss:2.2165
# epoch:235  d_loss:0.2629  g_loss:2.5678
# epoch:236  d_loss:0.4350  g_loss:2.1199
# epoch:237  d_loss:0.3635  g_loss:2.7418
# epoch:238  d_loss:0.2964  g_loss:2.6228
# epoch:239  d_loss:0.3031  g_loss:2.1978
# epoch:240  d_loss:0.3967  g_loss:2.1399
# epoch:241  d_loss:0.3993  g_loss:2.2247
# epoch:242  d_loss:0.4262  g_loss:2.1723
# epoch:243  d_loss:0.4498  g_loss:2.0522
# epoch:244  d_loss:0.3144  g_loss:2.3950
# epoch:245  d_loss:0.3961  g_loss:2.5187
# epoch:246  d_loss:0.3141  g_loss:1.9685
# epoch:247  d_loss:0.3367  g_loss:2.2032
# epoch:248  d_loss:0.3671  g_loss:2.3987
# epoch:249  d_loss:0.4014  g_loss:2.4246
# epoch:250  d_loss:0.3393  g_loss:2.9743
# epoch:251  d_loss:0.4064  g_loss:2.7203
# epoch:252  d_loss:0.4013  g_loss:2.4575
# epoch:253  d_loss:0.4545  g_loss:2.4456
# epoch:254  d_loss:0.3016  g_loss:1.7119
# epoch:255  d_loss:0.4569  g_loss:2.0542
# epoch:256  d_loss:0.3562  g_loss:2.5276
# epoch:257  d_loss:0.3313  g_loss:2.4580
# epoch:258  d_loss:0.4216  g_loss:2.2160
# epoch:259  d_loss:0.6430  g_loss:2.1797
# epoch:260  d_loss:0.3682  g_loss:1.4448
# epoch:261  d_loss:0.5696  g_loss:1.8636
# epoch:262  d_loss:0.6339  g_loss:1.8380
# epoch:263  d_loss:0.6174  g_loss:1.7768
# epoch:264  d_loss:0.7714  g_loss:1.5969
# epoch:265  d_loss:0.5843  g_loss:1.7503
# epoch:266  d_loss:0.6775  g_loss:1.1465
# epoch:267  d_loss:0.6697  g_loss:1.7229
# epoch:268  d_loss:0.8318  g_loss:1.4593
# epoch:269  d_loss:0.5632  g_loss:1.8953
# epoch:270  d_loss:0.5037  g_loss:1.4943
# epoch:271  d_loss:0.4354  g_loss:1.8703
# epoch:272  d_loss:0.4295  g_loss:1.5904
# epoch:273  d_loss:0.5051  g_loss:1.8177
# epoch:274  d_loss:0.6107  g_loss:1.5462
# epoch:275  d_loss:0.4536  g_loss:1.6031
# epoch:276  d_loss:0.5877  g_loss:1.9452
# epoch:277  d_loss:0.5704  g_loss:1.9109
# epoch:278  d_loss:0.3885  g_loss:1.9199
# epoch:279  d_loss:0.4595  g_loss:2.1712
# epoch:280  d_loss:0.4365  g_loss:2.1015
# epoch:281  d_loss:0.4950  g_loss:1.8442
# epoch:282  d_loss:0.4292  g_loss:1.9585
# epoch:283  d_loss:0.4443  g_loss:1.8738
# epoch:284  d_loss:0.3924  g_loss:2.1097
# epoch:285  d_loss:0.3391  g_loss:2.2668
# epoch:286  d_loss:0.3846  g_loss:2.6208
# epoch:287  d_loss:0.4278  g_loss:2.4044
# epoch:288  d_loss:0.2727  g_loss:2.9282
# epoch:289  d_loss:0.4158  g_loss:2.3712
# epoch:290  d_loss:0.4719  g_loss:1.9656
# epoch:291  d_loss:0.3749  g_loss:1.9723
# epoch:292  d_loss:0.3955  g_loss:2.1914
# epoch:293  d_loss:0.2745  g_loss:2.2319
# epoch:294  d_loss:0.3371  g_loss:2.6970
# epoch:295  d_loss:0.4294  g_loss:2.4929
# epoch:296  d_loss:0.3952  g_loss:2.4802
# epoch:297  d_loss:0.3292  g_loss:2.3367
# epoch:298  d_loss:0.3875  g_loss:1.8458
# epoch:299  d_loss:0.3142  g_loss:2.0588
# epoch:300  d_loss:0.5436  g_loss:1.9147
# epoch:301  d_loss:0.2895  g_loss:2.6467
# epoch:302  d_loss:0.3479  g_loss:2.4101
# epoch:303  d_loss:0.4146  g_loss:2.5900
# epoch:304  d_loss:0.3940  g_loss:2.7345
# epoch:305  d_loss:0.4596  g_loss:1.7900
# epoch:306  d_loss:0.3754  g_loss:1.5319
# epoch:307  d_loss:0.5149  g_loss:1.9766
# epoch:308  d_loss:0.3784  g_loss:2.6747
# epoch:309  d_loss:0.4204  g_loss:3.4370
# epoch:310  d_loss:0.4687  g_loss:2.7168
# epoch:311  d_loss:0.4372  g_loss:2.2237
# epoch:312  d_loss:0.4722  g_loss:1.8035
# epoch:313  d_loss:0.5070  g_loss:1.7334
# epoch:314  d_loss:0.4115  g_loss:1.7881
# epoch:315  d_loss:0.3070  g_loss:2.4646
# epoch:316  d_loss:0.3626  g_loss:2.7359
# epoch:317  d_loss:0.4956  g_loss:2.7553
# epoch:318  d_loss:0.6605  g_loss:2.5980
# epoch:319  d_loss:0.5545  g_loss:1.6589
# epoch:320  d_loss:0.6621  g_loss:1.2146
# epoch:321  d_loss:0.6273  g_loss:1.5934
# epoch:322  d_loss:0.4555  g_loss:2.2144
# epoch:323  d_loss:0.5756  g_loss:2.2462
# epoch:324  d_loss:0.6480  g_loss:1.9055
# epoch:325  d_loss:0.3631  g_loss:1.9558
# epoch:326  d_loss:0.5375  g_loss:1.7409
# epoch:327  d_loss:0.4672  g_loss:1.4524
# epoch:328  d_loss:0.4894  g_loss:1.6838
# epoch:329  d_loss:0.4825  g_loss:1.6471
# epoch:330  d_loss:0.4217  g_loss:1.5692
# epoch:331  d_loss:0.4462  g_loss:1.7655
# epoch:332  d_loss:0.3960  g_loss:1.8816
# epoch:333  d_loss:0.3921  g_loss:1.7540
# epoch:334  d_loss:0.3327  g_loss:1.8691
# epoch:335  d_loss:0.3714  g_loss:2.0068
# epoch:336  d_loss:0.4581  g_loss:1.9005
# epoch:337  d_loss:0.3025  g_loss:2.4981
# epoch:338  d_loss:0.2719  g_loss:2.2445
# epoch:339  d_loss:0.3715  g_loss:2.2634
# epoch:340  d_loss:0.2543  g_loss:2.2359
# epoch:341  d_loss:0.3674  g_loss:2.3854
# epoch:342  d_loss:0.4233  g_loss:2.2492
# epoch:343  d_loss:0.2106  g_loss:2.6130
# epoch:344  d_loss:0.2541  g_loss:2.2709
# epoch:345  d_loss:0.2983  g_loss:2.6223
# epoch:346  d_loss:0.3354  g_loss:2.3719
# epoch:347  d_loss:0.2598  g_loss:2.1841
# epoch:348  d_loss:0.2305  g_loss:2.7696
# epoch:349  d_loss:0.2087  g_loss:3.2939
# epoch:350  d_loss:0.3253  g_loss:3.0280
# epoch:351  d_loss:0.2306  g_loss:3.1237
# epoch:352  d_loss:0.2837  g_loss:3.0337
# epoch:353  d_loss:0.3340  g_loss:2.1278
# epoch:354  d_loss:0.4463  g_loss:2.1993
# epoch:355  d_loss:0.3642  g_loss:2.0362
# epoch:356  d_loss:0.3327  g_loss:2.4059
# epoch:357  d_loss:0.3957  g_loss:2.4552
# epoch:358  d_loss:0.3605  g_loss:2.5239
# epoch:359  d_loss:0.3030  g_loss:2.7371
# epoch:360  d_loss:0.4331  g_loss:2.1441
# epoch:361  d_loss:0.5049  g_loss:2.6438
# epoch:362  d_loss:0.2806  g_loss:2.6136
# epoch:363  d_loss:0.4769  g_loss:2.1309
# epoch:364  d_loss:0.3907  g_loss:2.2036
# epoch:365  d_loss:0.3343  g_loss:2.3762
# epoch:366  d_loss:0.5543  g_loss:1.8601
# epoch:367  d_loss:0.4677  g_loss:1.5865
# epoch:368  d_loss:0.5128  g_loss:1.8257
# epoch:369  d_loss:0.3919  g_loss:1.8788
# epoch:370  d_loss:0.4529  g_loss:2.2043
# epoch:371  d_loss:0.3786  g_loss:2.5247
# epoch:372  d_loss:0.3751  g_loss:1.9260
# epoch:373  d_loss:0.4029  g_loss:1.8673
# epoch:374  d_loss:0.4069  g_loss:1.9180
# epoch:375  d_loss:0.4953  g_loss:1.9230
# epoch:376  d_loss:0.4265  g_loss:2.1083
# epoch:377  d_loss:0.3968  g_loss:2.2157
# epoch:378  d_loss:0.3425  g_loss:2.5839
# epoch:379  d_loss:0.3468  g_loss:2.2169
# epoch:380  d_loss:0.4691  g_loss:1.7953
# epoch:381  d_loss:0.2951  g_loss:1.8103
# epoch:382  d_loss:0.2992  g_loss:1.9670
# epoch:383  d_loss:0.3996  g_loss:1.8288
# epoch:384  d_loss:0.3548  g_loss:1.8799
# epoch:385  d_loss:0.3947  g_loss:1.9810
# epoch:386  d_loss:0.3170  g_loss:2.2630
# epoch:387  d_loss:0.2545  g_loss:2.6393
# epoch:388  d_loss:0.3620  g_loss:2.3525
# epoch:389  d_loss:0.2996  g_loss:2.5009
# epoch:390  d_loss:0.4198  g_loss:2.4003
# epoch:391  d_loss:0.3046  g_loss:2.4326
# epoch:392  d_loss:0.3730  g_loss:2.3878
# epoch:393  d_loss:0.3510  g_loss:2.8940
# epoch:394  d_loss:0.2746  g_loss:2.7149
# epoch:395  d_loss:0.3481  g_loss:2.7289
# epoch:396  d_loss:0.3124  g_loss:2.0978
# epoch:397  d_loss:0.2937  g_loss:2.2590
# epoch:398  d_loss:0.3348  g_loss:2.0119
# epoch:399  d_loss:0.3884  g_loss:2.0710
# epoch:400  d_loss:0.2378  g_loss:2.7321
# epoch:401  d_loss:0.1744  g_loss:2.9218
# epoch:402  d_loss:0.2655  g_loss:2.9897
# epoch:403  d_loss:0.2598  g_loss:2.4513
# epoch:404  d_loss:0.2767  g_loss:2.2853
# epoch:405  d_loss:0.1929  g_loss:2.0678
# epoch:406  d_loss:0.3782  g_loss:1.7357
# epoch:407  d_loss:0.2197  g_loss:2.9262
# epoch:408  d_loss:0.2103  g_loss:2.7431
# epoch:409  d_loss:0.3011  g_loss:2.7705
# epoch:410  d_loss:0.3128  g_loss:2.2975
# epoch:411  d_loss:0.2679  g_loss:1.6703
# epoch:412  d_loss:0.2589  g_loss:1.9734
# epoch:413  d_loss:0.2041  g_loss:2.4513
# epoch:414  d_loss:0.2936  g_loss:2.6371
# epoch:415  d_loss:0.3053  g_loss:3.2172
# epoch:416  d_loss:0.3592  g_loss:2.4239
# epoch:417  d_loss:0.3346  g_loss:2.2533
# epoch:418  d_loss:0.2828  g_loss:2.3770
# epoch:419  d_loss:0.3334  g_loss:2.4307
# epoch:420  d_loss:0.4996  g_loss:2.5536
# epoch:421  d_loss:0.1935  g_loss:2.5966
# epoch:422  d_loss:0.4220  g_loss:2.4801
# epoch:423  d_loss:0.3955  g_loss:2.3914
# epoch:424  d_loss:0.4854  g_loss:2.0107
# epoch:425  d_loss:0.2271  g_loss:3.0875
# epoch:426  d_loss:0.3258  g_loss:2.5566
# epoch:427  d_loss:0.3066  g_loss:3.0635
# epoch:428  d_loss:0.3367  g_loss:2.4841
# epoch:429  d_loss:0.4158  g_loss:2.2965
# epoch:430  d_loss:0.3398  g_loss:1.6465
# epoch:431  d_loss:0.3333  g_loss:2.4560
# epoch:432  d_loss:0.2793  g_loss:3.2379
# epoch:433  d_loss:0.5567  g_loss:2.6777
# epoch:434  d_loss:0.4807  g_loss:2.1197
# epoch:435  d_loss:0.3542  g_loss:2.2308
# epoch:436  d_loss:0.3705  g_loss:2.4063
# epoch:437  d_loss:0.3190  g_loss:3.0880
# epoch:438  d_loss:0.4503  g_loss:2.7638
# epoch:439  d_loss:0.2978  g_loss:2.4755
# epoch:440  d_loss:0.3329  g_loss:2.1078
# epoch:441  d_loss:0.2798  g_loss:2.4725
# epoch:442  d_loss:0.2170  g_loss:2.4475
# epoch:443  d_loss:0.1655  g_loss:2.9254
# epoch:444  d_loss:0.2681  g_loss:2.6535
# epoch:445  d_loss:0.2224  g_loss:2.4492
# epoch:446  d_loss:0.2204  g_loss:2.4790
# epoch:447  d_loss:0.2305  g_loss:2.1871
# epoch:448  d_loss:0.3038  g_loss:2.7265
# epoch:449  d_loss:0.2377  g_loss:2.7088
# epoch:450  d_loss:0.2095  g_loss:3.1377
# epoch:451  d_loss:0.2212  g_loss:3.1395
# epoch:452  d_loss:0.1797  g_loss:2.3636
# epoch:453  d_loss:0.2206  g_loss:2.6374
# epoch:454  d_loss:0.1434  g_loss:2.9232
# epoch:455  d_loss:0.2779  g_loss:2.4782
# epoch:456  d_loss:0.2057  g_loss:2.4669
# epoch:457  d_loss:0.2109  g_loss:3.0672
# epoch:458  d_loss:0.2007  g_loss:3.1003
# epoch:459  d_loss:0.1944  g_loss:2.9256
# epoch:460  d_loss:0.1632  g_loss:2.9340
# epoch:461  d_loss:0.2295  g_loss:2.9253
# epoch:462  d_loss:0.1950  g_loss:3.4726
# epoch:463  d_loss:0.1806  g_loss:3.4941
# epoch:464  d_loss:0.1283  g_loss:3.0221
# epoch:465  d_loss:0.2523  g_loss:2.2231
# epoch:466  d_loss:0.1817  g_loss:2.7905
# epoch:467  d_loss:0.2174  g_loss:2.4285
# epoch:468  d_loss:0.1854  g_loss:3.3639
# epoch:469  d_loss:0.1995  g_loss:3.6693
# epoch:470  d_loss:0.4643  g_loss:3.5001
# epoch:471  d_loss:0.1889  g_loss:3.1926
# epoch:472  d_loss:0.2524  g_loss:2.8477
# epoch:473  d_loss:0.2999  g_loss:2.3879
# epoch:474  d_loss:0.1992  g_loss:2.7308
# epoch:475  d_loss:0.3273  g_loss:2.5366
# epoch:476  d_loss:0.2554  g_loss:2.9083
# epoch:477  d_loss:0.2216  g_loss:3.1272
# epoch:478  d_loss:0.3665  g_loss:2.3117
# epoch:479  d_loss:0.3396  g_loss:1.8668
# epoch:480  d_loss:0.3207  g_loss:1.7704
# epoch:481  d_loss:0.3508  g_loss:2.2113
# epoch:482  d_loss:0.4411  g_loss:2.7804
# epoch:483  d_loss:0.3272  g_loss:3.0439
# epoch:484  d_loss:0.2452  g_loss:2.7390
# epoch:485  d_loss:0.3009  g_loss:2.7181
# epoch:486  d_loss:0.3664  g_loss:2.3319
# epoch:487  d_loss:0.2112  g_loss:2.5107
# epoch:488  d_loss:0.1824  g_loss:2.7207
# epoch:489  d_loss:0.2075  g_loss:2.3325
# epoch:490  d_loss:0.2840  g_loss:2.5201
# epoch:491  d_loss:0.1583  g_loss:2.7978
# epoch:492  d_loss:0.2043  g_loss:2.7254
# epoch:493  d_loss:0.2401  g_loss:3.4248
# epoch:494  d_loss:0.1358  g_loss:3.8327
# epoch:495  d_loss:0.2543  g_loss:2.3192
# epoch:496  d_loss:0.2353  g_loss:2.5454
# epoch:497  d_loss:0.2149  g_loss:2.1774
# epoch:498  d_loss:0.2010  g_loss:2.8801
# epoch:499  d_loss:0.1946  g_loss:3.1283
# epoch:500  d_loss:0.1219  g_loss:3.9177
# epoch:501  d_loss:0.1611  g_loss:3.3497
# epoch:502  d_loss:0.2734  g_loss:2.7660
# epoch:503  d_loss:0.1761  g_loss:2.3056
# epoch:504  d_loss:0.1283  g_loss:2.3832
# epoch:505  d_loss:0.1408  g_loss:2.6140
# epoch:506  d_loss:0.1497  g_loss:3.0194
# epoch:507  d_loss:0.1798  g_loss:3.7914
# epoch:508  d_loss:0.1661  g_loss:3.6002
# epoch:509  d_loss:0.1078  g_loss:3.5124
# epoch:510  d_loss:0.1763  g_loss:3.0331
# epoch:511  d_loss:0.2010  g_loss:3.3241
# epoch:512  d_loss:0.3159  g_loss:2.9734
# epoch:513  d_loss:0.1608  g_loss:3.0896
# epoch:514  d_loss:0.1927  g_loss:3.4175
# epoch:515  d_loss:0.1345  g_loss:3.5452
# epoch:516  d_loss:0.2124  g_loss:3.6035
# epoch:517  d_loss:0.1961  g_loss:3.2920
# epoch:518  d_loss:0.2301  g_loss:2.5864
# epoch:519  d_loss:0.2029  g_loss:2.5190
# epoch:520  d_loss:0.1587  g_loss:3.3193
# epoch:521  d_loss:0.1311  g_loss:3.6785
# epoch:522  d_loss:0.2079  g_loss:3.0006
# epoch:523  d_loss:0.2275  g_loss:2.1733
# epoch:524  d_loss:0.2375  g_loss:2.6704
# epoch:525  d_loss:0.2428  g_loss:2.8649
# epoch:526  d_loss:0.2361  g_loss:2.6783
# epoch:527  d_loss:0.3087  g_loss:2.8893
# epoch:528  d_loss:0.4111  g_loss:1.7728
# epoch:529  d_loss:0.2018  g_loss:1.9575
# epoch:530  d_loss:0.1822  g_loss:2.4594
# epoch:531  d_loss:0.2173  g_loss:2.8360
# epoch:532  d_loss:0.1909  g_loss:3.0051
# epoch:533  d_loss:0.2409  g_loss:2.2754
# epoch:534  d_loss:0.2949  g_loss:2.0139
# epoch:535  d_loss:0.2726  g_loss:2.7719
# epoch:536  d_loss:0.1458  g_loss:3.3567
# epoch:537  d_loss:0.2771  g_loss:2.6873
# epoch:538  d_loss:0.4798  g_loss:1.9834
# epoch:539  d_loss:0.3645  g_loss:1.3753
# epoch:540  d_loss:0.2719  g_loss:2.1252
# epoch:541  d_loss:0.2790  g_loss:2.1197
# epoch:542  d_loss:0.2831  g_loss:2.1176
# epoch:543  d_loss:0.3305  g_loss:1.4715
# epoch:544  d_loss:0.2455  g_loss:1.9200
# epoch:545  d_loss:0.2115  g_loss:1.8796
# epoch:546  d_loss:0.2418  g_loss:2.9589
# epoch:547  d_loss:0.2595  g_loss:2.3430
# epoch:548  d_loss:0.2939  g_loss:2.6656
# epoch:549  d_loss:0.2263  g_loss:2.7989
# epoch:550  d_loss:0.2206  g_loss:2.4829
# epoch:551  d_loss:0.1090  g_loss:2.4889
# epoch:552  d_loss:0.2831  g_loss:2.4704
# epoch:553  d_loss:0.2439  g_loss:2.2501
# epoch:554  d_loss:0.3036  g_loss:1.7495
# epoch:555  d_loss:0.1439  g_loss:2.1160
# epoch:556  d_loss:0.1379  g_loss:2.8106
# epoch:557  d_loss:0.2116  g_loss:2.8457
# epoch:558  d_loss:0.2433  g_loss:2.8079
# epoch:559  d_loss:0.3568  g_loss:2.3636
# epoch:560  d_loss:0.2777  g_loss:2.5108
# epoch:561  d_loss:0.2997  g_loss:4.1790
# epoch:562  d_loss:0.1482  g_loss:4.7513
# epoch:563  d_loss:0.2797  g_loss:3.7889
# epoch:564  d_loss:0.7802  g_loss:2.2564
# epoch:565  d_loss:0.3811  g_loss:2.3536
# epoch:566  d_loss:0.2781  g_loss:3.5669
# epoch:567  d_loss:0.2905  g_loss:4.1647
# epoch:568  d_loss:0.4370  g_loss:3.3745
# epoch:569  d_loss:0.4399  g_loss:3.0837
# epoch:570  d_loss:0.5061  g_loss:1.8254
# epoch:571  d_loss:0.3986  g_loss:2.2995
# epoch:572  d_loss:0.4058  g_loss:2.6142
# epoch:573  d_loss:0.2983  g_loss:3.1167
# epoch:574  d_loss:0.4946  g_loss:2.7122
# epoch:575  d_loss:0.4619  g_loss:1.9088
# epoch:576  d_loss:0.4158  g_loss:1.6832
# epoch:577  d_loss:0.2430  g_loss:2.2329
# epoch:578  d_loss:0.2917  g_loss:2.3132
# epoch:579  d_loss:0.4401  g_loss:2.2949
# epoch:580  d_loss:0.3961  g_loss:1.9628
# epoch:581  d_loss:0.4888  g_loss:1.4813
# epoch:582  d_loss:0.5001  g_loss:1.9074
# epoch:583  d_loss:0.5541  g_loss:1.8571
# epoch:584  d_loss:0.4146  g_loss:2.2581
# epoch:585  d_loss:0.3440  g_loss:2.7424
# epoch:586  d_loss:0.3228  g_loss:2.8637
# epoch:587  d_loss:0.5074  g_loss:2.3372
# epoch:588  d_loss:0.3799  g_loss:3.1883
# epoch:589  d_loss:1.4278  g_loss:1.4982
# epoch:590  d_loss:0.9288  g_loss:0.8729
# epoch:591  d_loss:1.0366  g_loss:1.1503
# epoch:592  d_loss:0.6445  g_loss:2.4698
# epoch:593  d_loss:0.7042  g_loss:1.9385
# epoch:594  d_loss:0.4585  g_loss:2.0866
# epoch:595  d_loss:1.0706  g_loss:1.5427
# epoch:596  d_loss:0.5932  g_loss:0.9964
# epoch:597  d_loss:0.7476  g_loss:1.1164
# epoch:598  d_loss:0.4995  g_loss:1.1932
# epoch:599  d_loss:0.6208  g_loss:1.2894
# epoch:600  d_loss:0.6754  g_loss:1.3038
# epoch:601  d_loss:0.4364  g_loss:1.5028
# epoch:602  d_loss:0.5232  g_loss:1.9065
# epoch:603  d_loss:0.5737  g_loss:1.4668
# epoch:604  d_loss:0.6187  g_loss:1.1023
# epoch:605  d_loss:0.4967  g_loss:1.0241
# epoch:606  d_loss:0.3440  g_loss:0.8683
# epoch:607  d_loss:0.3257  g_loss:1.3241
# epoch:608  d_loss:0.2867  g_loss:1.1139
# epoch:609  d_loss:0.2601  g_loss:1.4108
# epoch:610  d_loss:0.2183  g_loss:1.7716
# epoch:611  d_loss:0.2575  g_loss:2.1870
# epoch:612  d_loss:0.3153  g_loss:1.9503
# epoch:613  d_loss:0.3479  g_loss:1.6530
# epoch:614  d_loss:0.3242  g_loss:1.5509
# epoch:615  d_loss:0.4167  g_loss:1.5271
# epoch:616  d_loss:0.4880  g_loss:1.6343
# epoch:617  d_loss:0.5696  g_loss:1.9488
# epoch:618  d_loss:0.5890  g_loss:2.0134
# epoch:619  d_loss:0.5960  g_loss:1.6098
# epoch:620  d_loss:0.8162  g_loss:1.1533
# epoch:621  d_loss:0.6034  g_loss:0.7846
# epoch:622  d_loss:0.7742  g_loss:0.6931
# epoch:623  d_loss:0.6978  g_loss:0.7532
# epoch:624  d_loss:0.6373  g_loss:0.7729
# epoch:625  d_loss:0.6637  g_loss:0.9781
# epoch:626  d_loss:0.7759  g_loss:1.0649
# epoch:627  d_loss:0.5745  g_loss:1.5512
# epoch:628  d_loss:0.6608  g_loss:1.0805
# epoch:629  d_loss:0.4763  g_loss:0.9168
# epoch:630  d_loss:0.7212  g_loss:0.8915
# epoch:631  d_loss:0.5710  g_loss:1.1401
# epoch:632  d_loss:0.5412  g_loss:1.4010
# epoch:633  d_loss:0.6816  g_loss:1.6178
# epoch:634  d_loss:0.6767  g_loss:1.2513
# epoch:635  d_loss:0.6628  g_loss:1.0977
# epoch:636  d_loss:0.5733  g_loss:1.4528
# epoch:637  d_loss:0.5948  g_loss:1.7591
# epoch:638  d_loss:0.6606  g_loss:2.0601
# epoch:639  d_loss:0.5356  g_loss:1.5238
# epoch:640  d_loss:0.4488  g_loss:1.5407
# epoch:641  d_loss:0.5571  g_loss:1.2212
# epoch:642  d_loss:0.6170  g_loss:1.5956
# epoch:643  d_loss:0.7087  g_loss:1.5399
# epoch:644  d_loss:0.4900  g_loss:1.9522
# epoch:645  d_loss:0.8340  g_loss:2.0058
# epoch:646  d_loss:0.6770  g_loss:1.4516
# epoch:647  d_loss:0.5163  g_loss:1.3198
# epoch:648  d_loss:0.5115  g_loss:1.2626
# epoch:649  d_loss:0.7572  g_loss:1.2872
# epoch:650  d_loss:0.5797  g_loss:1.5657
# epoch:651  d_loss:0.8650  g_loss:1.4050
# epoch:652  d_loss:0.5109  g_loss:1.6777
# epoch:653  d_loss:0.4931  g_loss:1.6557
# epoch:654  d_loss:0.5532  g_loss:1.6251
# epoch:655  d_loss:0.4882  g_loss:1.4286
# epoch:656  d_loss:0.5668  g_loss:1.8240
# epoch:657  d_loss:0.4327  g_loss:1.8371
# epoch:658  d_loss:0.4076  g_loss:2.0954
# epoch:659  d_loss:0.2462  g_loss:2.1414
# epoch:660  d_loss:0.2842  g_loss:2.0894
# epoch:661  d_loss:0.2515  g_loss:2.4603
# epoch:662  d_loss:0.1966  g_loss:2.4399
# epoch:663  d_loss:0.2477  g_loss:2.2979
# epoch:664  d_loss:0.2371  g_loss:2.5132
# epoch:665  d_loss:0.2143  g_loss:2.5486
# epoch:666  d_loss:0.1942  g_loss:3.0142
# epoch:667  d_loss:0.1421  g_loss:3.1711
# epoch:668  d_loss:0.2523  g_loss:2.8095
# epoch:669  d_loss:0.2439  g_loss:2.7176
# epoch:670  d_loss:0.1659  g_loss:2.8054
# epoch:671  d_loss:0.2657  g_loss:2.6294
# epoch:672  d_loss:0.2981  g_loss:2.7575
# epoch:673  d_loss:0.2309  g_loss:2.0479
# epoch:674  d_loss:0.3248  g_loss:2.1022
# epoch:675  d_loss:0.4081  g_loss:2.4303
# epoch:676  d_loss:0.2535  g_loss:2.8877
# epoch:677  d_loss:0.5163  g_loss:2.6912
# epoch:678  d_loss:0.5880  g_loss:2.1844
# epoch:679  d_loss:0.4517  g_loss:2.2081
# epoch:680  d_loss:0.4841  g_loss:2.2026
# epoch:681  d_loss:0.5171  g_loss:1.6209
# epoch:682  d_loss:0.4774  g_loss:1.7505
# epoch:683  d_loss:0.5580  g_loss:1.5835
# epoch:684  d_loss:0.3500  g_loss:1.9874
# epoch:685  d_loss:0.3060  g_loss:1.9779
# epoch:686  d_loss:0.6074  g_loss:1.4987
# epoch:687  d_loss:0.4867  g_loss:1.2774
# epoch:688  d_loss:0.4783  g_loss:1.3142
# epoch:689  d_loss:0.4894  g_loss:1.4150
# epoch:690  d_loss:0.4578  g_loss:2.0034
# epoch:691  d_loss:0.4814  g_loss:1.8393
# epoch:692  d_loss:0.4535  g_loss:1.8897
# epoch:693  d_loss:0.3902  g_loss:1.6976
# epoch:694  d_loss:0.4325  g_loss:1.5513
# epoch:695  d_loss:0.3315  g_loss:1.8584
# epoch:696  d_loss:0.3368  g_loss:2.0098
# epoch:697  d_loss:0.3201  g_loss:2.1949
# epoch:698  d_loss:0.2891  g_loss:2.3197
# epoch:699  d_loss:0.2845  g_loss:2.3664
# epoch:700  d_loss:0.2174  g_loss:2.3688
# epoch:701  d_loss:0.3099  g_loss:2.1351
# epoch:702  d_loss:0.2519  g_loss:2.0553
# epoch:703  d_loss:0.3473  g_loss:1.8758
# epoch:704  d_loss:0.2265  g_loss:2.5145
# epoch:705  d_loss:0.3443  g_loss:2.0685
# epoch:706  d_loss:0.2342  g_loss:2.5863
# epoch:707  d_loss:0.3275  g_loss:3.0125
# epoch:708  d_loss:0.3561  g_loss:2.8489
# epoch:709  d_loss:0.4011  g_loss:2.0992
# epoch:710  d_loss:0.3321  g_loss:2.4598
# epoch:711  d_loss:0.3352  g_loss:2.2861
# epoch:712  d_loss:0.3388  g_loss:2.6253
# epoch:713  d_loss:0.4755  g_loss:1.9022
# epoch:714  d_loss:0.2400  g_loss:2.7034
# epoch:715  d_loss:0.4049  g_loss:2.5571
# epoch:716  d_loss:0.3459  g_loss:2.8469
# epoch:717  d_loss:0.4685  g_loss:2.5014
# epoch:718  d_loss:0.3950  g_loss:2.0712
# epoch:719  d_loss:0.3289  g_loss:2.1394
# epoch:720  d_loss:0.5300  g_loss:2.0425
# epoch:721  d_loss:0.5697  g_loss:1.4857
# epoch:722  d_loss:0.3745  g_loss:2.0203
# epoch:723  d_loss:0.6032  g_loss:1.7760
# epoch:724  d_loss:0.4329  g_loss:1.9572
# epoch:725  d_loss:0.7888  g_loss:1.9601
# epoch:726  d_loss:0.5777  g_loss:1.8276
# epoch:727  d_loss:0.5863  g_loss:1.5046
# epoch:728  d_loss:0.5043  g_loss:1.6008
# epoch:729  d_loss:0.4740  g_loss:2.0645
# epoch:730  d_loss:0.3216  g_loss:2.2537
# epoch:731  d_loss:0.3065  g_loss:2.6416
# epoch:732  d_loss:0.2892  g_loss:2.4926
# epoch:733  d_loss:0.4325  g_loss:2.2322
# epoch:734  d_loss:0.3198  g_loss:1.7138
# epoch:735  d_loss:0.3103  g_loss:2.0069
# epoch:736  d_loss:0.2180  g_loss:2.3744
# epoch:737  d_loss:0.2939  g_loss:2.9849
# epoch:738  d_loss:0.2902  g_loss:2.7259
# epoch:739  d_loss:0.2698  g_loss:2.6788
# epoch:740  d_loss:0.4634  g_loss:2.1595
# epoch:741  d_loss:0.4475  g_loss:1.9689
# epoch:742  d_loss:0.4111  g_loss:2.4639
# epoch:743  d_loss:0.2841  g_loss:2.4963
# epoch:744  d_loss:0.3827  g_loss:2.6398
# epoch:745  d_loss:0.3703  g_loss:2.6259
# epoch:746  d_loss:0.4364  g_loss:3.1083
# epoch:747  d_loss:0.2880  g_loss:2.7834
# epoch:748  d_loss:0.2785  g_loss:2.6757
# epoch:749  d_loss:0.3323  g_loss:2.4447
# epoch:750  d_loss:0.3574  g_loss:2.1286
# epoch:751  d_loss:0.4915  g_loss:1.8742
# epoch:752  d_loss:0.4226  g_loss:1.8426
# epoch:753  d_loss:0.3923  g_loss:2.2085
# epoch:754  d_loss:0.3760  g_loss:2.6196
# epoch:755  d_loss:0.4722  g_loss:2.3479
# epoch:756  d_loss:0.6870  g_loss:2.0455
# epoch:757  d_loss:0.5224  g_loss:2.0512
# epoch:758  d_loss:0.5454  g_loss:1.9962
# epoch:759  d_loss:0.3932  g_loss:1.7729
# epoch:760  d_loss:0.4533  g_loss:1.8825
# epoch:761  d_loss:0.4120  g_loss:1.8876
# epoch:762  d_loss:0.6073  g_loss:1.6435
# epoch:763  d_loss:0.5020  g_loss:1.8504
# epoch:764  d_loss:0.5059  g_loss:1.8316
# epoch:765  d_loss:0.6166  g_loss:1.7697
# epoch:766  d_loss:0.5602  g_loss:1.3886
# epoch:767  d_loss:0.2876  g_loss:2.1257
# epoch:768  d_loss:0.4035  g_loss:2.1862
# epoch:769  d_loss:0.3355  g_loss:1.9144
# epoch:770  d_loss:0.4137  g_loss:2.1178
# epoch:771  d_loss:0.3435  g_loss:2.3134
# epoch:772  d_loss:0.3402  g_loss:2.0504
# epoch:773  d_loss:0.3112  g_loss:2.2742
# epoch:774  d_loss:0.3359  g_loss:1.8252
# epoch:775  d_loss:0.4928  g_loss:1.5396
# epoch:776  d_loss:0.2734  g_loss:2.4078
# epoch:777  d_loss:0.2490  g_loss:2.4246
# epoch:778  d_loss:0.3503  g_loss:2.5161
# epoch:779  d_loss:0.3236  g_loss:2.4983
# epoch:780  d_loss:0.2765  g_loss:2.3823
# epoch:781  d_loss:0.3028  g_loss:2.5519
# epoch:782  d_loss:0.3275  g_loss:2.3248
# epoch:783  d_loss:0.2359  g_loss:2.3448
# epoch:784  d_loss:0.2412  g_loss:2.2132
# epoch:785  d_loss:0.3396  g_loss:2.5886
# epoch:786  d_loss:0.2975  g_loss:3.1480
# epoch:787  d_loss:0.2467  g_loss:2.9279
# epoch:788  d_loss:0.4057  g_loss:2.4738
# epoch:789  d_loss:0.2825  g_loss:2.2004
# epoch:790  d_loss:0.4552  g_loss:2.5357
# epoch:791  d_loss:0.3141  g_loss:3.1313
# epoch:792  d_loss:0.3705  g_loss:2.6680
# epoch:793  d_loss:0.3562  g_loss:2.6073
# epoch:794  d_loss:0.3424  g_loss:2.1150
# epoch:795  d_loss:0.2689  g_loss:1.8356
# epoch:796  d_loss:0.4731  g_loss:2.0793
# epoch:797  d_loss:0.4163  g_loss:2.2381
# epoch:798  d_loss:0.4084  g_loss:2.8122
# epoch:799  d_loss:0.3745  g_loss:3.0692
# epoch:800  d_loss:0.3533  g_loss:2.7858
# epoch:801  d_loss:0.4554  g_loss:2.1577
# epoch:802  d_loss:0.6395  g_loss:1.7874
# epoch:803  d_loss:0.6243  g_loss:1.2586
# epoch:804  d_loss:0.5259  g_loss:1.4764
# epoch:805  d_loss:0.5292  g_loss:1.6684
# epoch:806  d_loss:0.6503  g_loss:1.7559
# epoch:807  d_loss:0.4252  g_loss:2.0517
# epoch:808  d_loss:0.4854  g_loss:1.8407
# epoch:809  d_loss:0.5604  g_loss:1.7640
# epoch:810  d_loss:0.5095  g_loss:1.8094
# epoch:811  d_loss:0.3492  g_loss:1.8444
# epoch:812  d_loss:0.4736  g_loss:1.6712
# epoch:813  d_loss:0.4191  g_loss:1.4155
# epoch:814  d_loss:0.5350  g_loss:1.4221
# epoch:815  d_loss:0.5467  g_loss:1.4047
# epoch:816  d_loss:0.3590  g_loss:1.9786
# epoch:817  d_loss:0.2409  g_loss:2.6591
# epoch:818  d_loss:0.3488  g_loss:2.4606
# epoch:819  d_loss:0.4701  g_loss:2.1782
# epoch:820  d_loss:0.5096  g_loss:1.9189
# epoch:821  d_loss:0.3092  g_loss:1.4925
# epoch:822  d_loss:0.2981  g_loss:1.9594
# epoch:823  d_loss:0.4323  g_loss:1.7670
# epoch:824  d_loss:0.4786  g_loss:1.8767
# epoch:825  d_loss:0.4224  g_loss:1.9076
# epoch:826  d_loss:0.3563  g_loss:1.9093
# epoch:827  d_loss:0.3425  g_loss:2.1535
# epoch:828  d_loss:0.2750  g_loss:2.3114
# epoch:829  d_loss:0.2955  g_loss:2.0344
# epoch:830  d_loss:0.3331  g_loss:2.3634
# epoch:831  d_loss:0.4779  g_loss:1.9504
# epoch:832  d_loss:0.2722  g_loss:2.2235
# epoch:833  d_loss:0.2776  g_loss:2.5122
# epoch:834  d_loss:0.3143  g_loss:2.4619
# epoch:835  d_loss:0.2495  g_loss:2.5393
# epoch:836  d_loss:0.2841  g_loss:2.0778
# epoch:837  d_loss:0.2326  g_loss:2.3292
# epoch:838  d_loss:0.2569  g_loss:2.0263
# epoch:839  d_loss:0.2667  g_loss:2.2775
# epoch:840  d_loss:0.2142  g_loss:2.4376
# epoch:841  d_loss:0.2229  g_loss:2.6364
# epoch:842  d_loss:0.4077  g_loss:2.1424
# epoch:843  d_loss:0.3122  g_loss:2.2090
# epoch:844  d_loss:0.2483  g_loss:2.3112
# epoch:845  d_loss:0.3263  g_loss:2.0498
# epoch:846  d_loss:0.3368  g_loss:2.4563
# epoch:847  d_loss:0.3670  g_loss:2.1108
# epoch:848  d_loss:0.3043  g_loss:1.7580
# epoch:849  d_loss:0.4511  g_loss:1.4462
# epoch:850  d_loss:0.3351  g_loss:1.9778
# epoch:851  d_loss:0.5491  g_loss:1.4116
# epoch:852  d_loss:0.5746  g_loss:1.5866
# epoch:853  d_loss:0.4654  g_loss:1.7596
# epoch:854  d_loss:0.3509  g_loss:2.0853
# epoch:855  d_loss:0.4655  g_loss:1.7336
# epoch:856  d_loss:0.5704  g_loss:1.4968
# epoch:857  d_loss:0.5597  g_loss:1.3130
# epoch:858  d_loss:0.4461  g_loss:2.0103
# epoch:859  d_loss:0.4914  g_loss:1.7718
# epoch:860  d_loss:0.5204  g_loss:1.6474
# epoch:861  d_loss:0.4309  g_loss:1.7680
# epoch:862  d_loss:0.6447  g_loss:1.5105
# epoch:863  d_loss:0.6058  g_loss:1.6536
# epoch:864  d_loss:0.4075  g_loss:1.8406
# epoch:865  d_loss:0.3398  g_loss:2.0220
# epoch:866  d_loss:0.6118  g_loss:1.9676
# epoch:867  d_loss:0.4517  g_loss:1.7154
# epoch:868  d_loss:0.5393  g_loss:1.3216
# epoch:869  d_loss:0.4252  g_loss:1.3449
# epoch:870  d_loss:0.4258  g_loss:1.5324
# epoch:871  d_loss:0.4571  g_loss:1.5725
# epoch:872  d_loss:0.3160  g_loss:2.1362
# epoch:873  d_loss:0.4666  g_loss:2.0576
# epoch:874  d_loss:0.2928  g_loss:2.0528
# epoch:875  d_loss:0.4409  g_loss:2.5128
# epoch:876  d_loss:0.4438  g_loss:1.8029
# epoch:877  d_loss:0.2691  g_loss:1.9281
# epoch:878  d_loss:0.2665  g_loss:1.9363
# epoch:879  d_loss:0.3150  g_loss:2.1987
# epoch:880  d_loss:0.3158  g_loss:2.1608
# epoch:881  d_loss:0.2417  g_loss:2.3979
# epoch:882  d_loss:0.4252  g_loss:2.3846
# epoch:883  d_loss:0.2185  g_loss:2.4983
# epoch:884  d_loss:0.3581  g_loss:2.5008
# epoch:885  d_loss:0.2982  g_loss:2.1237
# epoch:886  d_loss:0.3214  g_loss:2.1007
# epoch:887  d_loss:0.4019  g_loss:2.3332
# epoch:888  d_loss:0.3725  g_loss:2.3413
# epoch:889  d_loss:0.4230  g_loss:2.1178
# epoch:890  d_loss:0.2841  g_loss:2.3310
# epoch:891  d_loss:0.4754  g_loss:2.1258
# epoch:892  d_loss:0.4683  g_loss:1.7609
# epoch:893  d_loss:0.5109  g_loss:1.8851
# epoch:894  d_loss:0.4908  g_loss:2.0507
# epoch:895  d_loss:0.5154  g_loss:2.0735
# epoch:896  d_loss:0.5193  g_loss:2.2991
# epoch:897  d_loss:0.5661  g_loss:2.0622
# epoch:898  d_loss:0.4585  g_loss:1.3613
# epoch:899  d_loss:0.5185  g_loss:1.4045
# epoch:900  d_loss:0.3920  g_loss:1.9229
# epoch:901  d_loss:0.4922  g_loss:2.0837
# epoch:902  d_loss:0.4544  g_loss:1.7753
# epoch:903  d_loss:0.5394  g_loss:2.4097
# epoch:904  d_loss:0.4619  g_loss:1.8890
# epoch:905  d_loss:0.4752  g_loss:1.5432
# epoch:906  d_loss:0.3420  g_loss:1.9093
# epoch:907  d_loss:0.3463  g_loss:1.9515
# epoch:908  d_loss:0.3052  g_loss:2.0405
# epoch:909  d_loss:0.3279  g_loss:1.9882
# epoch:910  d_loss:0.3672  g_loss:2.4806
# epoch:911  d_loss:0.3198  g_loss:2.1115
# epoch:912  d_loss:0.2243  g_loss:2.1439
# epoch:913  d_loss:0.2930  g_loss:2.2861
# epoch:914  d_loss:0.3088  g_loss:2.1417
# epoch:915  d_loss:0.2533  g_loss:2.2950
# epoch:916  d_loss:0.2751  g_loss:2.5941
# epoch:917  d_loss:0.3636  g_loss:2.5458
# epoch:918  d_loss:0.3865  g_loss:2.0963
# epoch:919  d_loss:0.3975  g_loss:1.9430
# epoch:920  d_loss:0.2856  g_loss:2.4458
# epoch:921  d_loss:0.4086  g_loss:2.5360
# epoch:922  d_loss:0.3849  g_loss:2.3263
# epoch:923  d_loss:0.4162  g_loss:1.7892
# epoch:924  d_loss:0.3412  g_loss:2.0044
# epoch:925  d_loss:0.5538  g_loss:1.7773
# epoch:926  d_loss:0.3604  g_loss:1.9133
# epoch:927  d_loss:0.5164  g_loss:1.9158
# epoch:928  d_loss:0.4995  g_loss:1.7652
# epoch:929  d_loss:0.4538  g_loss:2.1203
# epoch:930  d_loss:0.5419  g_loss:1.9129
# epoch:931  d_loss:0.3625  g_loss:2.1317
# epoch:932  d_loss:0.4532  g_loss:1.8169
# epoch:933  d_loss:0.3889  g_loss:2.1480
# epoch:934  d_loss:0.4066  g_loss:1.8030
# epoch:935  d_loss:0.4244  g_loss:1.9481
# epoch:936  d_loss:0.4759  g_loss:2.0822
# epoch:937  d_loss:0.3608  g_loss:2.1564
# epoch:938  d_loss:0.4224  g_loss:2.3254
# epoch:939  d_loss:0.3186  g_loss:2.2385
# epoch:940  d_loss:0.3503  g_loss:2.3567
# epoch:941  d_loss:0.3889  g_loss:2.5423
# epoch:942  d_loss:0.3476  g_loss:2.6983
# epoch:943  d_loss:0.3036  g_loss:2.3746
# epoch:944  d_loss:0.2146  g_loss:2.7807
# epoch:945  d_loss:0.2651  g_loss:2.7442
# epoch:946  d_loss:0.3604  g_loss:1.8785
# epoch:947  d_loss:0.4692  g_loss:1.8642
# epoch:948  d_loss:0.3661  g_loss:2.4913
# epoch:949  d_loss:0.4417  g_loss:2.7289
# epoch:950  d_loss:0.4230  g_loss:2.6669
# epoch:951  d_loss:0.3619  g_loss:2.7244
# epoch:952  d_loss:0.5456  g_loss:2.1964
# epoch:953  d_loss:0.4595  g_loss:1.7049
# epoch:954  d_loss:0.5034  g_loss:1.7338
# epoch:955  d_loss:0.5668  g_loss:1.7340
# epoch:956  d_loss:0.4743  g_loss:1.9776
# epoch:957  d_loss:0.6067  g_loss:1.8251
# epoch:958  d_loss:0.5894  g_loss:1.9962
# epoch:959  d_loss:0.5994  g_loss:1.8808
# epoch:960  d_loss:0.5041  g_loss:1.6457
# epoch:961  d_loss:0.4905  g_loss:1.4745
# epoch:962  d_loss:0.6253  g_loss:1.7920
# epoch:963  d_loss:0.4036  g_loss:2.1665
# epoch:964  d_loss:0.4587  g_loss:1.8465
# epoch:965  d_loss:0.5212  g_loss:2.1751
# epoch:966  d_loss:0.5151  g_loss:1.4812
# epoch:967  d_loss:0.4086  g_loss:1.7724
# epoch:968  d_loss:0.3990  g_loss:2.0193
